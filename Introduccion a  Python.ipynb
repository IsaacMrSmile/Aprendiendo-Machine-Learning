# %% [markdown]
# <a href="https://colab.research.google.com/github/IsaacMrSmile/Aprendiendo-Machine-Learning/blob/main/Introduccion%20a%20%20Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##Las variables

# %% [markdown]
# ## Manejo de Strings en Python

# %%
string = "Hola a todos!"
string1 = "Soy un Pokemon"
string2 = "Hola"
print(string[7])

# %%
nuevostring = string + string1
print(nuevostring)

# %%
print(string[6:12])

# %%
stringconespacios ="   Hola , ¿ ves los espacios?   "
print(len(stringconespacios))
